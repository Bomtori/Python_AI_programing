# %% [markdown]
# # 사용한 키워드 + 옵션 수정사항
# - 키워드 : teris, war, cinematic animation,  soldier girl, block, robot
# - 옵션 수정사항
# 1. PROMPT_STEPS : 235
# 2. FIDELITY: 0.8
# 3. SHARPEN_AMOUNT: 1
# 4. INPAINT_STRENGTH: 0.24
# 5. INPAINT_MODE_STEPS: 275
# 6. INIT_STRENGTH: 0.29

# %% [markdown]
# #이미지
# ![군인 3.png](data:image/png;base64,...)
